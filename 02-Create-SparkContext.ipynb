# %%
# Set the PySpark environment variables
import os
os.environ['SPARK_HOME'] = "/Software/spark-4.2.0-hadoop3"
os.environ['PYSPARK_DRIVER_PYTHON'] = 'jupyter'
os.environ['PYSPARK_DRIVER_PYTHON_OPTS'] = 'lab'
os.environ['PYSPARK_PYTHON'] = 'python'

# %%
# Import SparkSession
from pyspark.sql import SparkSession

# %%
# Create a SparkSession
spark = SparkSession.builder.appName("PySparkSession").getOrCreate()

# %%
# Get the SparkContext from the SparkSession
sc = spark.sparkContext

# %%
# Show details about SparkContext
sc
# Out:
# <SparkContext master=local[*] appName=PySparkSession>

# %%
# Shut down the current active SparkContext
sc.stop() # or spark.stop()

# %%
# Shut down the current active SparkSession
spark.stop()
